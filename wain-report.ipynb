# %%
wain = pd.read_csv('./data/adam-wainwright.csv')
wain.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(wain.shape)
wain.head()
# Out:
# (3068, 89)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FC  2021-09-28           86.4          -1.10           6.25
# 1         FC  2021-09-28           85.9          -1.09           6.36
# 2         SI  2021-09-28           89.9          -1.08           6.23
# 3         FC  2021-09-28           85.9          -1.05           6.25
# 4         SI  2021-09-28           90.9          -1.09           6.18
#
#         player_name  batter  pitcher     events      description  zone  \
# 0  Wainwright, Adam  500871   425794        out    hit_into_play    12
# 1  Wainwright, Adam  500871   425794        NaN    called_strike     2
# 2  Wainwright, Adam  621438   425794  strikeout  swinging_strike     3
# 3  Wainwright, Adam  621438   425794        NaN             foul     3
# 4  Wainwright, Adam  621438   425794        NaN    called_strike     9
#
#                                                  des game_type stand p_throws  \
# 0  Eduardo Escobar grounds out to first baseman P...         R     L        R
# 1  Eduardo Escobar grounds out to first baseman P...         R     L        R
# 2                Tyrone Taylor strikes out swinging.         R     R        R
# 3                Tyrone Taylor strikes out swinging.         R     R        R
# 4                Tyrone Taylor strikes out swinging.         R     R        R
#
#   home_team away_team type  hit_location      bb_type  balls  strikes  \
# 0       STL       MIL    X           3.0  ground_ball      0        1
# 1       STL       MIL    S           NaN          NaN      0        0
# 2       STL       MIL    S           2.0          NaN      2        2
# 3       STL       MIL    S           NaN          NaN      2        1
# 4       STL       MIL    S           NaN          NaN      2        0
#
#    game_year  pfx_x  pfx_z  plate_x  plate_z  on_3b     on_2b     on_1b  \
# 0       2021   0.49   7.44     0.88     2.43    NaN  649966.0  607054.0
# 1       2021   0.42   3.96     0.20     2.86    NaN  649966.0  607054.0
# 2       2021  -0.65  14.52     0.68     2.99    NaN  649966.0  607054.0
# 3       2021   0.65   5.76     0.65     3.26    NaN  649966.0  607054.0
# 4       2021  -1.10   8.16     0.54     1.78    NaN  649966.0  607054.0
#
#    outs_when_up  inning inning_topbot    hc_x    hc_y  fielder_2       vx0  \
# 0             2       6           Top  155.84  165.13     668800  3.730995
# 1             2       6           Top     NaN     NaN     668800  2.210030
# 2             1       6           Top     NaN     NaN     668800  5.784091
# 3             1       6           Top     NaN     NaN     668800  2.719844
# 4             1       6           Top     NaN     NaN     668800  6.501698
#
#           vy0       vz0         ax         ay         az  sz_top  sz_bot  \
# 0 -125.873064 -4.270794   4.660825  21.797698 -24.938079    3.30    1.50
# 1 -125.192475 -2.755686   4.050163  23.188532 -28.415463    3.02    1.43
# 2 -130.855154 -4.669285  -8.647461  27.030423 -17.496824    3.30    1.61
# 3 -125.179497 -1.890460   6.428149  21.811586 -26.928095    3.30    1.61
# 4 -132.240721 -6.659546 -14.292993  25.861898 -22.961406    3.21    1.62
#
#    hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# 0             20.0          60.1          -4.0             87.4
# 1              NaN           NaN           NaN             86.6
# 2              NaN           NaN           NaN             90.9
# 3            152.0          71.3          25.0             86.8
# 4              NaN           NaN           NaN             92.0
#
#    release_spin_rate  release_extension  game_pk  pitcher.1  fielder_2.1  \
# 0             2422.0                6.5   632314     425794       668800
# 1             2382.0                6.5   632314     425794       668800
# 2             2192.0                6.8   632314     425794       668800
# 3             2403.0                6.5   632314     425794       668800
# 4             2271.0                6.8   632314     425794       668800
#
#    fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  \
# 0     502671     669242     571448     657557     641933     664056
# 1     502671     669242     571448     657557     641933     664056
# 2     502671     669242     571448     657557     641933     664056
# 3     502671     669242     571448     657557     641933     664056
# 4     502671     669242     571448     657557     641933     664056
#
#    fielder_9  release_pos_y  estimated_ba_using_speedangle  \
# 0     666185          53.97                            0.1
# 1     666185          54.04                            NaN
# 2     666185          53.66                            NaN
# 3     666185          54.03                            NaN
# 4     666185          53.74                            NaN
#
#    estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                            0.092         0.0         1.0          0.0
# 1                              NaN         NaN         NaN          NaN
# 2                              NaN         0.0         1.0          0.0
# 3                              NaN         NaN         NaN          NaN
# 4                              NaN         NaN         NaN          NaN
#
#    iso_value  launch_speed_angle  at_bat_number  pitch_number pitch_name  \
# 0        0.0                 2.0             51             2     Cutter
# 1        NaN                 NaN             51             1     Cutter
# 2        0.0                 NaN             50             5     Sinker
# 3        NaN                 NaN             50             4     Cutter
# 4        NaN                 NaN             50             3     Sinker
#
#    home_score  away_score  bat_score  fld_score  post_away_score  \
# 0           4           2          2          4                2
# 1           4           2          2          4                2
# 2           4           2          2          4                2
# 3           4           2          2          4                2
# 4           4           2          2          4                2
#
#    post_home_score  post_bat_score  post_fld_score if_fielding_alignment  \
# 0                4               2               4             Strategic
# 1                4               2               4             Strategic
# 2                4               2               4              Standard
# 3                4               2               4              Standard
# 4                4               2               4              Standard
#
#   of_fielding_alignment  spin_axis  delta_home_win_exp  delta_run_exp  \
# 0             Strategic      183.0               0.058         -0.366
# 1              Standard      166.0               0.000         -0.075
# 2              Standard      199.0               0.064         -0.433
# 3              Standard      142.0               0.000         -0.138
# 4              Standard      205.0               0.000         -0.149
#
#    is_strike pitch_count  plate_-x  pfx_-x  swing_miss
# 0          1         0-1     -0.88   -5.88           0
# 1          1         0-0     -0.20   -5.04           0
# 2          1         2-2     -0.68    7.80           1
# 3          1         2-1     -0.65   -7.80           0
# 4          1         2-0     -0.54   13.20           0
