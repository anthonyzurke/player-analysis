# %% [markdown]
# - [Imports](#Imports)
# - [Data](#Data)
# - [Spray Chart](#Spray-Chart)
#     - [PHI Home Field Spray Chart](#PHI-Spray-Chart)
# - [Pitch Usage & Counts](#Pitch-Usage-&-Counts)
#     - [Pitch Usage by Pitcher Handedness](#Pitch-Usage-by-Pitcher-Handedness)
#     - [Pitch Type by Count](#Pitch-Type-by-Count)
# - [Pitch Location](#Pitch-Locations)
#     - [Pitch Location - All-Pitches](#Pitch-Location--All-Pitches)
# - [Heatmaps](#Heatmaps)
#     - [Fastball Heatmaps](#Fastball-Heatmaps)
#     - [Slider Heatmaps](#Slider-Heatmaps)
#     - [Changeup Heatmaps](#Changeup-Heatmaps)
#     - [Sinker Heatmaps](#Sinker-Heatmaps)
#     - [Curveball Heatmaps](#Curveball-Heatmaps)
#     - [Cutter Heatmaps](#Cutter-Heatmaps)
#     - [Split-Finger Heatmaps](#Split-Finger-Heatmaps)
#     - [Knuckle Curve Heatmaps](#Knuckle-Curve-Heatmaps)
#     - [Slow Curve Heatmaps](#Slow-Curve-Heatmaps)

# %% [markdown]
# # Imports

# %%
 from pybaseball import spraychart
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
from matplotlib.ticker import PercentFormatter

import warnings
warnings.filterwarnings('ignore')

# %%
swanson = pd.read_csv('../data/dansby-swanson.csv')
swanson.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(swanson.shape)
swanson.head(2)
# Out:
# (2578, 91)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-03           92.0           -2.0           5.19
# 1         FF  2021-10-03           93.5           -2.1           5.13
#
#        player_name  batter  pitcher     events      description  zone  \
# 0  Swanson, Dansby  621020   592866  strikeout  swinging_strike     3
# 1  Swanson, Dansby  621020   592866        NaN             foul    12
#
#                                     des game_type stand p_throws home_team  \
# 0  Dansby Swanson strikes out swinging.         R     R        R       ATL
# 1  Dansby Swanson strikes out swinging.         R     R        R       ATL
#
#   away_team type  hit_location bb_type  balls  strikes  game_year  pfx_x  \
# 0       NYM    S           2.0     NaN      1        2       2021   0.14
# 1       NYM    S           NaN     NaN      1        2       2021   0.01
#
#    pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0   8.28     0.53     3.26    NaN    NaN    NaN             2       6
# 1   9.48     0.87     2.74    NaN    NaN    NaN             2       6
#
#   inning_topbot  hc_x  hc_y  fielder_2       vx0         vy0       vz0  \
# 0           Bot   NaN   NaN     664850  6.170758 -133.962806 -0.638454
# 1           Bot   NaN   NaN     664850  7.673758 -136.110030 -2.235441
#
#          ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0  0.603948  24.763260 -23.806454    3.41    1.56              NaN
# 1 -1.328747  25.813549 -22.006688    3.41    1.56            273.0
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0           NaN           NaN             93.5             2208.0
# 1          82.4          30.0             94.7             2137.0
#
#    release_extension  game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                6.8   632254     592866       664850     624413     606299
# 1                6.7   632254     592866       664850     624413     606299
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0     542340     596019     642086     607043     624424          53.67
# 1     542340     596019     642086     607043     624424          53.84
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                            NaN                              NaN         0.0
# 1                            NaN                              NaN         NaN
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 NaN             46
# 1         NaN          NaN        NaN                 NaN             46
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0             5  4-Seam Fastball           5           0          5
# 1             4  4-Seam Fastball           5           0          5
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0          0                0                5               5
# 1          0                0                5               5
#
#    post_fld_score if_fielding_alignment of_fielding_alignment  spin_axis  \
# 0               0         Infield shift              Standard      203.0
# 1               0         Infield shift              Standard      210.0
#
#    delta_home_win_exp  delta_run_exp  is_strike pitch_count  plate_-x  pfx_-x  \
# 0              -0.001         -0.073          1         1-2     -0.53   -1.68
# 1               0.000          0.000          1         1-2     -0.87   -0.12
#
#    swing_miss  first_pitch_take  first_pitch_swing
# 0           1                 0                  0
# 1           0                 0                  0
