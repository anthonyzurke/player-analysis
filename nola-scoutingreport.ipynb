# %% [markdown]
# # Data

# %%
nola = pd.read_csv('./data/arron-nola.csv')
nola.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(nola.shape)
nola.head()
# Out:
# (2971, 89)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-09-29           93.3          -1.94           5.02
# 1         FF  2021-09-29           93.2          -1.97           5.09
# 2         KC  2021-09-29           78.2          -1.96           5.20
# 3         FC  2021-09-29           86.5          -1.92           5.13
# 4         FC  2021-09-29           86.4          -1.84           5.04
#
#    player_name  batter  pitcher     events      description  zone  \
# 0  Nola, Aaron  608331   605400  strikeout  swinging_strike    11
# 1  Nola, Aaron  608331   605400        NaN  swinging_strike    11
# 2  Nola, Aaron  608331   605400        NaN    called_strike     4
# 3  Nola, Aaron  621020   605400        out    hit_into_play     6
# 4  Nola, Aaron  621020   605400        NaN             foul     9
#
#                                                  des game_type stand p_throws  \
# 0                    Max Fried strikes out swinging.         R     L        R
# 1                    Max Fried strikes out swinging.         R     L        R
# 2                    Max Fried strikes out swinging.         R     L        R
# 3  Dansby Swanson flies out to right fielder Bryc...         R     R        R
# 4  Dansby Swanson flies out to right fielder Bryc...         R     R        R
#
#   home_team away_team type  hit_location   bb_type  balls  strikes  game_year  \
# 0       ATL       PHI    S           2.0       NaN      0        2       2021
# 1       ATL       PHI    S           NaN       NaN      0        1       2021
# 2       ATL       PHI    S           NaN       NaN      0        0       2021
# 3       ATL       PHI    X           9.0  fly_ball      0        1       2021
# 4       ATL       PHI    S           NaN       NaN      0        0       2021
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0  -1.24  13.08    -0.53     3.83    NaN    NaN    NaN             2       6
# 1  -1.18  14.76    -0.95     4.17    NaN    NaN    NaN             2       6
# 2   1.21 -10.20    -0.32     2.53    NaN    NaN    NaN             2       6
# 3   0.15   6.60     0.50     2.46    NaN    NaN    NaN             1       6
# 4  -0.02   7.80     0.58     1.62    NaN    NaN    NaN             1       6
#
#   inning_topbot    hc_x   hc_y  fielder_2       vx0         vy0       vz0  \
# 0           Bot     NaN    NaN     592663  6.437747 -135.594939  0.386420
# 1           Bot     NaN    NaN     592663  5.285874 -135.542919  0.789233
# 2           Bot     NaN    NaN     592663  1.288396 -113.711407  2.855818
# 3           Bot  204.45  84.98     592663  5.526223 -125.832710 -1.233450
# 4           Bot     NaN    NaN     592663  5.881789 -125.733945 -3.296232
#
#           ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0 -16.720704  33.118718 -19.230981    3.55    1.63              NaN
# 1 -15.751346  33.679947 -17.659463    3.55    1.63              NaN
# 2  10.101998  24.919587 -40.296728    3.44    1.56              NaN
# 3   0.413827  26.324683 -26.353234    3.41    1.56            341.0
# 4  -1.395159  25.453681 -24.778776    3.41    1.56              2.0
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0           NaN           NaN             93.8             2356.0
# 1           NaN           NaN             93.9             2452.0
# 2           NaN           NaN             78.3             2609.0
# 3          96.8          35.0             87.4             2161.0
# 4          55.6         -44.0             87.6             2128.0
#
#    release_extension  game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                6.9   632306     605400       592663     663837     516416
# 1                7.0   632306     605400       592663     663837     516416
# 2                6.9   632306     605400       592663     663837     516416
# 3                7.0   632306     605400       592663     663837     516416
# 4                7.0   632306     605400       592663     663837     516416
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0     591720     544369     457705     546318     547180          53.60
# 1     591720     544369     457705     546318     547180          53.47
# 2     591720     544369     457705     546318     547180          53.64
# 3     591720     544369     457705     546318     547180          53.55
# 4     591720     544369     457705     546318     547180          53.48
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                            NaN                              NaN         0.0
# 1                            NaN                              NaN         NaN
# 2                            NaN                              NaN         NaN
# 3                          0.171                            0.309         0.0
# 4                            NaN                              NaN         NaN
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 NaN             49
# 1         NaN          NaN        NaN                 NaN             49
# 2         NaN          NaN        NaN                 NaN             49
# 3         1.0          0.0        0.0                 3.0             48
# 4         NaN          NaN        NaN                 NaN             48
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0             3  4-Seam Fastball           3           2          3
# 1             2  4-Seam Fastball           3           2          3
# 2             1    Knuckle Curve           3           2          3
# 3             2           Cutter           3           2          3
# 4             1           Cutter           3           2          3
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0          2                2                3               3
# 1          2                2                3               3
# 2          2                2                3               3
# 3          2                2                3               3
# 4          2                2                3               3
#
#    post_fld_score if_fielding_alignment of_fielding_alignment  spin_axis  \
# 0               2              Standard              Standard        237
# 1               2              Standard              Standard        234
# 2               2              Standard              Standard         55
# 3               2              Standard              Standard        217
# 4               2              Standard              Standard        236
#
#    delta_home_win_exp  delta_run_exp  is_strike pitch_count  plate_-x  pfx_-x  \
# 0              -0.010         -0.061          1         0-2      0.53   14.88
# 1               0.000         -0.024          1         0-1      0.95   14.16
# 2               0.000         -0.018          1         0-0      0.32  -14.52
# 3              -0.015         -0.136          1         0-1     -0.50   -1.80
# 4               0.000         -0.027          1         0-0     -0.58    0.24
#
#    swing_miss
# 0           1
# 1           1
# 2           0
# 3           0
# 4           0

# %%
nola.groupby(['pitch_type']).mean()
# Out:
#             release_speed  release_pos_x  release_pos_z         batter  \
# pitch_type
# CH              85.152801      -1.957385       4.936078  603630.497453
# FC              86.715217      -1.941522       5.163696  593229.195652
# FF              92.910883      -1.803970       5.078029  594111.251561
# KC              78.465668      -1.795418       5.189613  597952.715356
# SI              92.004348      -1.806884       5.046111  601674.792271
#
#              pitcher       zone  hit_location     balls   strikes  game_year  \
# pitch_type
# CH          605400.0  10.412564      4.682119  0.923599  1.037351     2021.0
# FC          605400.0   9.282609      6.750000  0.608696  0.782609     2021.0
# FF          605400.0   8.209634      5.373057  0.747547  0.809099     2021.0
# KC          605400.0   9.685393      4.401869  0.774032  1.046192     2021.0
# SI          605400.0   8.705314      5.096154  0.881643  1.089372     2021.0
#
#                pfx_x      pfx_z   plate_x   plate_z          on_3b  \
# pitch_type
# CH         -1.253090   2.206044 -0.430153  1.719491  627880.428571
# FC          0.081957   7.502609  0.463478  2.921522  623542.375000
# FF         -1.108029  14.189759  0.162489  2.703506  618747.067416
# KC          1.215768 -10.255281  0.338352  1.824095  625889.647887
# SI         -1.459275   8.795362  0.222174  2.502488  624070.106383
#
#                     on_2b          on_1b  outs_when_up    inning        hc_x  \
# pitch_type
# CH          614770.595238  596587.675676      0.933786  3.930390  128.856847
# FC          594124.250000  622932.133333      0.760870  3.760870  139.453333
# FF          601887.487342  595454.196552      0.960749  3.306869  128.106933
# KC          600374.631068  600067.705882      0.992509  3.536829  123.880000
# SI          614208.907407  595351.533333      0.951691  3.570048  135.602286
#
#                   hc_y      fielder_2       vx0         vy0       vz0  \
# pitch_type
# CH          132.372432  597155.828523  6.153890 -123.864648 -1.613383
# FC          128.270833  605454.869565  5.647802 -126.225020 -0.461484
# FF          112.029000  597779.567351  7.552581 -135.073045 -2.902424
# KC          120.771418  596337.906367  2.392907 -114.168697  1.239062
# SI          120.309571  597206.700483  8.422555 -133.712666 -2.206894
#
#                    ax         ay         az    sz_top    sz_bot  \
# pitch_type
# CH         -14.131822  24.831065 -30.149014  3.404109  1.573854
# FC          -0.250292  24.697405 -25.561269  3.364130  1.567391
# FF         -15.223739  29.890531 -17.260534  3.392105  1.575888
# KC          10.046868  23.360067 -40.076061  3.386030  1.567728
# SI         -19.331727  28.743024 -23.094890  3.388213  1.580531
#
#             hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# pitch_type
# CH                92.216346     82.794686     -1.739130        85.760441
# FC               144.478261     80.347826      7.869565        87.752174
# FF               196.552279     83.199729     32.363144        93.819804
# KC               119.040650     79.797541      2.286885        78.697753
# SI               145.168000     84.184000     15.624000        92.971498
#
#             release_spin_rate  release_extension        game_pk  pitcher.1  \
# pitch_type
# CH                1511.023769           6.708149  633515.674024   605400.0
# FC                2179.108696           6.839130  633608.130435   605400.0
# FF                2198.084746           6.910526  633459.929527   605400.0
# KC                2529.333333           6.709114  633429.470662   605400.0
# SI                2137.232446           6.925362  633210.927536   605400.0
#
#               fielder_2.1      fielder_3      fielder_4      fielder_5  \
# pitch_type
# CH          597155.828523  627124.979626  541523.578947  632847.232598
# FC          605454.869565  631494.173913  519622.108696  628396.326087
# FF          597779.567351  622709.415700  542512.465656  629340.710080
# KC          596337.906367  623178.363296  546274.805243  629701.489388
# SI          597206.700483  610623.149758  534769.048309  615731.794686
#
#                 fielder_6      fielder_7      fielder_8      fielder_9  \
# pitch_type
# CH          571209.315789  474992.086587  580873.142615  553910.949066
# FC          561681.413043  459631.369565  606440.630435  559806.152174
# FF          568696.289920  474736.797502  580899.608385  551013.462087
# KC          569747.651685  478866.129838  578961.429463  551558.258427
# SI          565525.676329  479301.968599  565149.091787  552681.108696
#
#             release_pos_y  estimated_ba_using_speedangle  \
# pitch_type
# CH              53.794329                       0.320108
# FC              53.665652                       0.230083
# FF              53.590865                       0.343007
# KC              53.790787                       0.316805
# SI              53.575628                       0.324243
#
#             estimated_woba_using_speedangle  woba_value  woba_denom  \
# pitch_type
# CH                                 0.335955    0.314634    1.000000
# FC                                 0.236750    0.288462    1.000000
# FF                                 0.434993    0.349111    0.995556
# KC                                 0.357947    0.274353    0.995690
# SI                                 0.336400    0.292105    0.991228
#
#             babip_value  iso_value  launch_speed_angle  at_bat_number  \
# pitch_type
# CH             0.207317   0.115854            2.936937      29.383701
# FC             0.153846   0.076923            2.500000      28.695652
# FF             0.186667   0.186667            3.569536      23.852810
# KC             0.159483   0.185345            3.203008      25.545568
# SI             0.210526   0.105263            3.271429      25.606280
#
#             pitch_number  home_score  away_score  bat_score  fld_score  \
# pitch_type
# CH              3.151104    1.696095    1.404075   1.275042   1.825127
# FC              2.478261    2.326087    1.021739   1.521739   1.826087
# FF              2.669938    1.399643    1.195361   0.998216   1.596789
# KC              2.995006    1.451935    1.178527   0.968789   1.661673
# SI              3.099034    1.222222    1.157005   1.111111   1.268116
#
#             post_away_score  post_home_score  post_bat_score  post_fld_score  \
# pitch_type
# CH                 1.414261         1.719864        1.308998        1.825127
# FC                 1.021739         2.369565        1.565217        1.826087
# FF                 1.202498         1.408564        1.014273        1.596789
# KC                 1.193508         1.476904        1.008739        1.661673
# SI                 1.171498         1.246377        1.149758        1.268116
#
#              spin_axis  delta_home_win_exp  delta_run_exp  is_strike  \
# pitch_type
# CH          256.135823           -0.000051       0.010092   0.650255
# FC          208.434783            0.003543      -0.008717   0.630435
# FF          229.447814            0.000814      -0.003394   0.666369
# KC           53.614232            0.000305      -0.005541   0.729089
# SI          229.125604            0.002775       0.007592   0.637681
#
#             plate_-x     pfx_-x  swing_miss
# pitch_type
# CH          0.430153  15.037080    0.173175
# FC         -0.463478  -0.983478    0.086957
# FF         -0.162489  13.296343    0.091882
# KC         -0.338352 -14.589213    0.184769
# SI         -0.222174  17.511304    0.053140

# %%
ff = nola.loc[nola['pitch_type'] == 'FF']
kc = nola.loc[nola['pitch_type'] == 'KC']
ch = nola.loc[nola['pitch_type'] == 'CH']
si = nola.loc[nola['pitch_type'] == 'SI']
fc = nola.loc[nola['pitch_type'] == 'FC']

r_ff = nola.loc[(nola['pitch_type'] == 'FF') & (nola['stand'] == 'R')]
r_kc = nola.loc[(nola['pitch_type'] == 'KC') & (nola['stand'] == 'R')]
r_ch = nola.loc[(nola['pitch_type'] == 'CH') & (nola['stand'] == 'R')]
r_si = nola.loc[(nola['pitch_type'] == 'SI') & (nola['stand'] == 'R')]
r_fc = nola.loc[(nola['pitch_type'] == 'FC') & (nola['stand'] == 'R')]

l_ff = nola.loc[(nola['pitch_type'] == 'FF') & (nola['stand'] == 'L')]
l_kc = nola.loc[(nola['pitch_type'] == 'KC') & (nola['stand'] == 'L')]
l_ch = nola.loc[(nola['pitch_type'] == 'CH') & (nola['stand'] == 'L')]
l_si = nola.loc[(nola['pitch_type'] == 'SI') & (nola['stand'] == 'L')]
l_fc = nola.loc[(nola['pitch_type'] == 'FC') & (nola['stand'] == 'L')]

# %% [markdown]
# # Pitcher Overview

# %% [markdown]
# ### Pitch Distribution

# %%
plt.figure(figsize = (8, 6))

dist = round(nola.pitch_type.value_counts(normalize = True), 2)
labels = ['FF', 'KC', 'CH', 'SI', 'FC']
color = sns.color_palette('coolwarm_r')

plt.pie(dist, labels = labels, colors = color, autopct = '%.0f%%')
plt.title('Distribution of Pitch Types - Aaron Nola', fontdict = font_title, pad = 15);

# %% [markdown]
# ### Velocity by Pitch Type

# %%
plt.figure(figsize = (8, 6))

sns.kdeplot(data = nola, x = 'release_speed', shade = 'fill', 
            multiple = 'layer', hue = 'pitch_type', 
            hue_order = ['FF', 'KC', 'CH', 'SI', 'FC'], 
            palette = 'tab10')
plt.title('Distribution of Velocity by Pitch Type', fontdict = font_title, pad = 15);
print('FF velo sits:', round(ff['release_speed'].quantile(.25)), '-', round(ff['release_speed'].quantile(.75)), 
      'mph, ', 'max:', round(ff['release_speed'].max(), 2), 'mph')
print('KC velo sits:', round(kc['release_speed'].quantile(.25)), '-', round(kc['release_speed'].quantile(.75)), 
      'mph, ', 'max:', round(kc['release_speed'].max(), 2), 'mph')
print('CH velo sits:', round(ch['release_speed'].quantile(.25)), '-', round(ch['release_speed'].quantile(.75)), 
      'mph, ', 'max:', round(ch['release_speed'].max(), 2), 'mph')
print('SI velo sits:', round(si['release_speed'].quantile(.25)), '-', round(si['release_speed'].quantile(.75)), 
      'mph, ', 'max:', round(si['release_speed'].max(), 2), 'mph')
print('FC velo sits:', round(fc['release_speed'].quantile(.25)), '-', round(fc['release_speed'].quantile(.75)), 
      'mph, ', 'max:', round(fc['release_speed'].max(), 2), 'mph');
# Out:
# FF velo sits: 92.0 - 94.0 mph,  max: 96.2 mph
# KC velo sits: 78.0 - 79.0 mph,  max: 81.9 mph
# CH velo sits: 84.0 - 86.0 mph,  max: 88.0 mph
# SI velo sits: 91.0 - 93.0 mph,  max: 95.2 mph
# FC velo sits: 86.0 - 88.0 mph,  max: 89.1 mph

# %% [markdown]
# # Pitcher Stuff

# %% [markdown]
# ### Velocity & Spin Rate

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(data = nola, x = 'release_speed', y = 'release_spin_rate', hue = 'pitch_type', 
                hue_order = ['FF', 'KC', 'CH', 'SI', 'FC'], palette = 'tab10')
plt.title('Speed vs Spin Rate - By Pitch Type', fontdict = font_title, pad = 15);

# %% [markdown]
# ### Horizontal & Vertical Break Axis

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(data = nola, x = 'pfx_-x', y = 'pfx_z', hue = 'pitch_type', 
                hue_order = ['FF', 'KC', 'CH', 'SI', 'FC'], palette = 'tab10')
plt.xlim(-30, 30)
plt.ylim(-30, 30)
plt.axhline(0, color = 'black')
plt.axvline(0, color = 'black')
plt.title('HB & VB Axis', fontdict = font_title, pad = 15);

# %% [markdown]
# ### Release Position

# %% [markdown]
# - from hitters' perspective*

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(data = nola, x = 'release_pos_x', y = 'release_pos_z', hue = 'pitch_type', palette = 'tab10')
plt.xlim(-4, 4)
plt.ylim(-1.5, 7.5)
plt.title('Release Position from Hitter Perspective', fontdict = font_title, pad = 15);

# %% [markdown]
# # Count Breakdown

# %%
blue = '#002D72'
orange = '#FF5910'
fig, axs = plt.subplots(3, 2, figsize = (15, 20))
fig.suptitle('Pitch Usage by Count', fontsize = 20, fontweight = 'bold')
plt.setp(axs[0:, :], xlabel = 'Count')
plt.setp(axs[:, 0:], ylabel = 'Frequency')
axs[0][0].hist(ff['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[0][0].set_title('Fastball Usage in Counts', fontsize = 15, pad = 15)
axs[0][1].hist(kc['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[0][1].set_title('Knuckle Curve Usage in Counts', fontsize = 15, pad = 15)
axs[1][0].hist(ch['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[1][0].set_title('Changeup Usage in Counts', fontsize = 15, pad = 15)
axs[1][1].hist(si['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[1][1].set_title('Sinker Usage in Counts', fontsize = 15, pad = 15)
axs[2][0].hist(fc['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[2][0].set_title('Cutter Usage in Counts', fontsize = 15, pad = 15)
axs[2][1].hist(nola['pitch_count'].sort_values(ascending = True), color = blue, edgecolor = orange, linewidth = 2)
axs[2][1].set_title('All Pitches in Counts', fontsize = 15, pad = 15)
plt.tight_layout();

# %% [markdown]
# ### Imports

# %%
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle

# %% [markdown]
# # Pitch Locations

# %% [markdown]
# ### Balls and Strikes from Hitters' Perspective

# %%
plt.figure(figsize = (8, 6))

sns.scatterplot(data = nola, x = 'plate_x', y = 'plate_z', hue = 'is_strike', palette = 'coolwarm')
left, bottom, width, height = (-.83, 1.5, 1.66, 1.82)
rect = mpatches.Rectangle((left, bottom), width, height,
                          fill = False, color = 'black', linewidth = 2)
plt.gca().add_patch(rect)
plt.title('Balls and Strikes - All Pitches', fontdict = font_title, pad = 15);

# %% [markdown]
# ### Balls and Strikes from Hitters' Perspective

# %%
plt.figure(figsize = (8, 6))

sns.kdeplot(data = nola, x = 'plate_x', y = 'plate_z', fill = True, cmap = 'coolwarm')
rect = mpatches.Rectangle((left, bottom), width, height,
                          fill = False, color = 'black', linewidth = 2)
plt.gca().add_patch(rect)
plt.title('Balls and Strikes - All Pitches', fontdict = font_title, pad = 15);

# %% [markdown]
# ### Fastball Heatmaps

# %% [markdown]
# *All from hitter perspective

# %%
fig, axs = plt.subplots(2, 3, figsize = (20, 12), sharex = True, sharey = True)
fig.suptitle('Fastball Heatmaps', fontsize = 20, fontweight = 'bold')
plt.axis(xmin = -3.5, xmax = 3.5)
plt.axis(ymin = -1.5, ymax = 5.5)

sns.scatterplot(ax = axs[0][0],data = r_ff,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[0][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][0].set_title('Location vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][1],data = r_ff,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[0][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][1].set_title('Swing and Miss vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][2],data = r_ff,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[0][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][2].set_title('WOBA Value vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][0],data = l_ff,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[1][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][0].set_title('Location vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][1],data = l_ff,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[1][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][1].set_title('Swing and Miss vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][2],data = l_ff,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[1][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][2].set_title('WOBA Value vs LHH', fontsize = 15, pad = 15);

# %% [markdown]
# ### Knuckle Curve Heatmaps

# %% [markdown]
# *All from hitter perspective

# %%
fig, axs = plt.subplots(2, 3, figsize = (20, 12), sharex = True, sharey = True)
fig.suptitle('Knuckle Curve Heatmaps', fontsize = 20, fontweight = 'bold')
plt.axis(xmin = -3.5, xmax = 3.5)
plt.axis(ymin = -1.5, ymax = 5.5)

sns.scatterplot(ax = axs[0][0],data = r_kc,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[0][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][0].set_title('Location vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][1],data = r_kc,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[0][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][1].set_title('Swing and Miss vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][2],data = r_kc,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[0][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][2].set_title('WOBA Value vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][0],data = l_kc,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[1][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][0].set_title('Location vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][1],data = l_kc,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[1][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][1].set_title('Swing and Miss vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][2],data = l_kc,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[1][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][2].set_title('WOBA Value vs LHH', fontsize = 15, pad = 15);

# %% [markdown]
# ### Changeup Heatmaps

# %% [markdown]
# *All from hitter perspective

# %%
fig, axs = plt.subplots(2, 3, figsize = (20, 12), sharex = True, sharey = True)
fig.suptitle('Changeup Heatmaps', fontsize = 20, fontweight = 'bold')
plt.axis(xmin = -3.5, xmax = 3.5)
plt.axis(ymin = -1.5, ymax = 5.5)

sns.scatterplot(ax = axs[0][0],data = r_ch,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[0][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][0].set_title('Location vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][1],data = r_ch,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[0][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][1].set_title('Swing and Miss vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][2],data = r_ch,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[0][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][2].set_title('WOBA Value vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][0],data = l_ch,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[1][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][0].set_title('Location vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][1],data = l_ch,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[1][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][1].set_title('Swing and Miss vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][2],data = l_ch,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[1][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][2].set_title('WOBA Value vs LHH', fontsize = 15, pad = 15);

# %% [markdown]
# ### Sinker Heatmaps

# %% [markdown]
# *All from hitter perspective

# %%
fig, axs = plt.subplots(2, 3, figsize = (20, 12), sharex = True, sharey = True)
fig.suptitle('Sinker Heatmaps', fontsize = 20, fontweight = 'bold')
plt.axis(xmin = -3.5, xmax = 3.5)
plt.axis(ymin = -1.5, ymax = 5.5)

sns.scatterplot(ax = axs[0][0],data = r_si,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[0][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][0].set_title('Location vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][1],data = r_si,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[0][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][1].set_title('Swing and Miss vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][2],data = r_si,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[0][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][2].set_title('WOBA Value vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][0],data = l_si,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[1][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][0].set_title('Location vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][1],data = l_si,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[1][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][1].set_title('Swing and Miss vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][2],data = l_si,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[1][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][2].set_title('WOBA Value vs LHH', fontsize = 15, pad = 15);

# %% [markdown]
# ### Cutter Heatmaps

# %% [markdown]
# *All from hitter perspective

# %%
fig, axs = plt.subplots(2, 3, figsize = (20, 12), sharex = True, sharey = True)
fig.suptitle('Cutter Heatmaps', fontsize = 20, fontweight = 'bold')
plt.axis(xmin = -3.5, xmax = 3.5)
plt.axis(ymin = -1.5, ymax = 5.5)

sns.scatterplot(ax = axs[0][0],data = r_fc,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[0][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][0].set_title('Location vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][1],data = r_fc,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[0][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][1].set_title('Swing and Miss vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[0][2],data = r_fc,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[0][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[0][2].set_title('WOBA Value vs RHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][0],data = l_fc,x = 'plate_x',y = 'plate_z',hue = 'is_strike',palette = 'coolwarm')
axs[1][0].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][0].set_title('Location vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][1],data = l_fc,x = 'plate_x',y = 'plate_z',hue = 'swing_miss',palette = 'coolwarm')
axs[1][1].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][1].set_title('Swing and Miss vs LHH', fontsize = 15, pad = 15)

sns.scatterplot(ax = axs[1][2],data = l_fc,x = 'plate_x',y = 'plate_z',hue = 'woba_value',palette = 'coolwarm')
axs[1][2].add_patch(Rectangle((-.83, 1.5), 1.66, 1.82, fill = False, color = 'black', linewidth = 2))
axs[1][2].set_title('WOBA Value vs LHH', fontsize = 15, pad = 15);
