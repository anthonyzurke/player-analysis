# %% [markdown]
# - [Imports](#Imports)
# - [Data](#Data)
# - [Pitcher Overview](#Pitcher-Overview)
#     - [Pitch Usage](#Pitch-Usage)
#     - [Pitch Usage by Batter Handedness](#Pitch-Usage-by-Batter-Handedness)
#     - [Velocity by Pitch Type](#Velocity-by-Pitch-Type)
# - [Pitcher Stuff](#Pitcher-Stuff)
#     - [Spin Axis](#Spin-Axis)
#     - [Velocity & Spin Rate](#Velocity-&-Spin-Rate)
#     - [HB & VB Axis](#Horizontal-&-Vertical-Break-Axis)
#     - [Release Position](#Release-Postion)
# - [Count Breakdown](#Count-Breakdown)
#     - [Pitch Usage by Count](#Pitch-Usage-by-Count)
# - [Pitch Locations](#Pitch-Locations)
#     - [Balls-&Strikes-from-Hitters' Perspective - All-Pitches](#Balls-&-Strikes-from-Hitters'-Perspective--All-Pitches)
# - [Heatmaps](#Heatmaps)
#     - [Slider Heatmaps](#Slider-Heatmaps)
#     - [Fastball Heatmaps](#Fastball-Heatmaps)
#     - [Curveball Heatmaps](#Curveball-Heatmaps)
#     - [Changeup Heatmaps](#Changeup-Heatmaps)

# %% [markdown]
# # Imports

# %%
from math import radians
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
from matplotlib.ticker import PercentFormatter

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
kimbrel = pd.read_csv('../data/craig-kimbrel.csv')
kimbrel.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 14,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(kimbrel.shape)
kimbrel.head(2)
# Out:
# (1008, 90)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-10-01           96.0          -3.15           4.66
# 1         FF  2021-10-01           96.5          -3.08           4.82
#
#       player_name  batter  pitcher events    description  zone  \
# 0  Kimbrel, Craig  605612   518886    out  hit_into_play   2.0
# 1  Kimbrel, Craig  605612   518886    NaN  called_strike   6.0
#
#                                                  des game_type stand p_throws  \
# 0  Harold Castro flies out to center fielder Luis...         R     L        R
# 1  Harold Castro flies out to center fielder Luis...         R     L        R
#
#   home_team away_team type  hit_location   bb_type  balls  strikes  game_year  \
# 0       CWS       DET    X           8.0  fly_ball      0        1       2021
# 1       CWS       DET    S           NaN       NaN      0        0       2021
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0  -0.80  13.08     0.05     2.96    NaN    NaN    NaN             2       8
# 1  -0.91  16.08     0.38     2.69    NaN    NaN    NaN             2       8
#
#   inning_topbot   hc_x   hc_y  fielder_2        vx0         vy0       vz0  \
# 0           Top  96.18  55.42     518735  10.270404 -139.413818 -1.331594
# 1           Top    NaN    NaN     518735  11.259937 -140.011728 -3.084673
#
#           ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0 -12.849801  32.440511 -17.944816    3.30    1.50            363.0
# 1 -14.632779  33.573937 -14.028565    3.36    1.65              NaN
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0          97.3          32.0             95.9             2339.0
# 1           NaN           NaN             96.0             2369.0
#
#    release_extension  game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                6.4   632274     518886       518735     547989     514917
# 1                6.3   632274     518886       518735     547989     514917
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0     660162     641313     571740     673357     544725          54.08
# 1     660162     641313     571740     673357     544725          54.18
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                          0.294                            0.509         0.0
# 1                            NaN                              NaN         NaN
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 5.0             72
# 1         NaN          NaN        NaN                 NaN             72
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0             2  4-Seam Fastball           8           1          1
# 1             1  4-Seam Fastball           8           1          1
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0          8                1                8               1
# 1          8                1                8               1
#
#    post_fld_score if_fielding_alignment of_fielding_alignment  spin_axis  \
# 0               8         Infield shift              Standard      228.0
# 1               8         Infield shift              Standard      227.0
#
#    delta_home_win_exp  delta_run_exp  is_strike pitch_count  plate_-x  pfx_-x  \
# 0                 0.0         -0.085          1         0-1     -0.05    9.60
# 1                 0.0         -0.018          1         0-0     -0.38   10.92
#
#    bauer_units  swing_miss
# 0    24.364583           0
# 1    24.549223           0
