# %% [markdown]
# - [Imports](#Imports)
# - [Data](#Data)
# - [Pitcher Overview](#Pitcher-Overview)
#     - [Pitch Usage](#Pitch-Usage)
#     - [Pitch Usage by Batter Handedness](#Pitch-Usage-by-Batter-Handedness)
#     - [Velocity by Pitch Type](#Velocity-by-Pitch-Type)
# - [Pitcher Stuff](#Pitcher-Stuff)
#     - [Spin Axis](#Spin-Axis)
#     - [Velocity & Spin Rate](#Velocity-&-Spin-Rate)
#     - [HB & VB Axis](#Horizontal-&-Vertical-Break-Axis)
#     - [Release Position](#Release-Postion)
# - [Count Breakdown](#Count-Breakdown)
#     - [Pitch Usage by Count](#Pitch-Usage-by-Count)
# - [Pitch Locations](#Pitch-Locations)
#     - [Balls-&Strikes-from-Hitters' Perspective - All-Pitches](#Balls-&-Strikes-from-Hitters'-Perspective--All-Pitches)
# - [Heatmaps](#Heatmaps)
#     - [Fastball Heatmaps](#Fastball-Heatmaps)
#     - [Split-Finger Heatmaps](#Split--Finger-Heatmaps)
#     - [Slider Heatmaps](#Slider-Heatmaps)

# %% [markdown]
# # Imports

# %%
from math import radians
import matplotlib.patches as mpatches
from matplotlib.patches import Rectangle
from matplotlib.ticker import PercentFormatter

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data

# %%
doolittle = pd.read_csv('../data/sean-doolittle.csv')
doolittle.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 14,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(doolittle.shape)
doolittle.head(2)
# Out:
# (1075, 90)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2019-09-28           93.3           2.31           5.92
# 1         FF  2019-09-28           93.1           2.28           5.92
#
#        player_name  batter  pitcher events    description  zone  \
# 0  Doolittle, Sean  475247   448281    out  hit_into_play  12.0
# 1  Doolittle, Sean  475247   448281    NaN  called_strike   5.0
#
#                                                 des game_type stand p_throws  \
# 0  Ryan Flaherty pops out to shortstop Trea Turner.         R     L        L
# 1  Ryan Flaherty pops out to shortstop Trea Turner.         R     L        L
#
#   home_team away_team type  hit_location bb_type  balls  strikes  game_year  \
# 0       WSH       CLE    X           6.0   popup      1        2       2019
# 1       WSH       CLE    S           NaN     NaN      1        1       2019
#
#    pfx_x  pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  outs_when_up  inning  \
# 0   0.22  19.80     0.32     3.87    NaN    NaN    NaN             2       9
# 1   0.41  20.04    -0.24     2.82    NaN    NaN    NaN             2       9
#
#   inning_topbot   hc_x    hc_y  fielder_2       vx0         vy0       vz0  \
# 0           Top  128.1  162.38     543228 -5.627512 -135.746020 -3.139576
# 1           Top    NaN     NaN     543228 -7.394281 -135.267352 -5.850137
#
#          ax         ay         az  sz_top  sz_bot  hit_distance_sc  \
# 0  4.014464  31.914404 -11.188363    3.72    1.78              NaN
# 1  6.771844  30.717113 -10.534932    3.66    1.70              NaN
#
#    launch_speed  launch_angle  effective_speed  release_spin_rate  \
# 0          80.0          69.0             93.5             2254.0
# 1           NaN           NaN             93.2             2224.0
#
#    release_extension  game_pk  pitcher.1  fielder_2.1  fielder_3  fielder_4  \
# 0                6.6   565974     448281       543228     475582     452678
# 1                6.5   565974     448281       543228     475582     452678
#
#    fielder_5  fielder_6  fielder_7  fielder_8  fielder_9  release_pos_y  \
# 0     543685     607208     665742     572191     467827          53.94
# 1     543685     607208     665742     572191     467827          53.95
#
#    estimated_ba_using_speedangle  estimated_woba_using_speedangle  woba_value  \
# 0                            0.0                              0.0         0.0
# 1                            NaN                              NaN         NaN
#
#    woba_denom  babip_value  iso_value  launch_speed_angle  at_bat_number  \
# 0         1.0          0.0        0.0                 3.0             80
# 1         NaN          NaN        NaN                 NaN             80
#
#    pitch_number       pitch_name  home_score  away_score  bat_score  \
# 0             4  4-Seam Fastball          10           7          7
# 1             3  4-Seam Fastball          10           7          7
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# 0         10                7               10               7
# 1         10                7               10               7
#
#    post_fld_score if_fielding_alignment of_fielding_alignment  spin_axis  \
# 0              10              Standard              Standard      173.0
# 1              10              Standard              Standard      166.0
#
#    delta_home_win_exp  delta_run_exp  is_strike pitch_count  plate_-x  pfx_-x  \
# 0               0.004         -0.081          1         1-2     -0.32   -2.64
# 1               0.000         -0.028          1         1-1      0.24   -4.92
#
#    bauer_units  swing_miss
# 0    24.158628           0
# 1    23.888292           0

# %%
doolittle.groupby('pitch_type').mean()
# Out:
#             release_speed  release_pos_x  release_pos_z         batter  \
# pitch_type
# FF              93.455649       2.163780       5.960866  562800.888068
# FS              83.710769       2.600308       5.640462  566905.046154
# SL              80.935484       2.572258       5.760968  543587.193548
#
#              pitcher       zone  hit_location     balls   strikes  game_year  \
# pitch_type
# FF          448281.0   7.640971      5.386473  0.826822  0.990496     2019.0
# FS          448281.0  11.030769      4.818182  0.707692  1.369231     2019.0
# SL          448281.0   9.370968      5.000000  0.467742  1.241935     2019.0
#
#                pfx_x      pfx_z   plate_x   plate_z          on_3b  \
# pitch_type
# FF          0.315502  19.597128 -0.024308  3.000982  531376.583333
# FS          1.134923  16.000615  0.446154  1.814308            NaN
# SL         -0.725161   2.856774 -0.736129  2.087097  550512.000000
#
#                     on_2b          on_1b  outs_when_up    inning        hc_x  \
# pitch_type
# FF          556953.917051  546038.288690      1.121436  8.898627  118.311899
# FS          554196.750000  552848.200000      1.123077  9.000000  106.582500
# SL          574958.166667  535637.933333      0.967742  8.693548  117.048889
#
#                   hc_y      fielder_2       vx0         vy0       vz0  \
# pitch_type
# FF          109.560506  498941.583949 -6.289576 -135.873413 -5.420283
# FS          109.132500  486908.830769 -7.136146 -121.623140 -4.997086
# SL          122.774444  508825.435484 -5.956534 -117.684626 -2.028781
#
#                    ax         ay         az    sz_top    sz_bot  \
# pitch_type
# FF           5.189318  28.230766 -11.171458  3.372587  1.596294
# FS          12.508518  22.350507 -18.320675  3.338000  1.587385
# SL          -5.553376  20.474316 -29.837727  3.304516  1.569194
#
#             hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# pitch_type
# FF               201.116352     83.516817     30.495495        93.177297
# FS               162.444444     77.838889     23.111111        83.435385
# SL               175.857143     74.620000     27.133333        80.167742
#
#             release_spin_rate  release_extension        game_pk  pitcher.1  \
# pitch_type
# FF                2214.995776           6.056072  566136.929250   448281.0
# FS                2136.307692           6.049231  566125.938462   448281.0
# SL                2423.822222           5.619355  566109.225806   448281.0
#
#               fielder_2.1      fielder_3      fielder_4      fielder_5  \
# pitch_type
# FF          498941.583949  502857.578669  544931.686378  535448.554382
# FS          486908.830769  501334.600000  535823.276923  537813.553846
# SL          508825.435484  500193.096774  535756.822581  541933.016129
#
#                 fielder_6      fielder_7      fielder_8      fielder_9  \
# pitch_type
# FF          606837.761352  651940.713833  632664.333685  584618.800422
# FS          607290.369231  653562.615385  638553.292308  567059.092308
# SL          605333.709677  658213.564516  636543.451613  584963.629032
#
#             release_pos_y  estimated_ba_using_speedangle  \
# pitch_type
# FF              54.443041                       0.323462
# FS              54.448615                       0.355000
# SL              54.886774                       0.259222
#
#             estimated_woba_using_speedangle  woba_value  woba_denom  \
# pitch_type
# FF                                 0.396667    0.332543     0.99569
# FS                                 0.370750    0.420833     1.00000
# SL                                 0.244222    0.138462     1.00000
#
#             babip_value  iso_value  launch_speed_angle  at_bat_number  \
# pitch_type
# FF             0.198276   0.193966            3.493590      72.017951
# FS             0.250000   0.333333            3.125000      72.569231
# SL             0.153846   0.000000            2.666667      70.064516
#
#             pitch_number  home_score  away_score  bat_score  fld_score  \
# pitch_type
# FF              3.087645    4.292503    4.067582   3.240760   5.119324
# FS              3.753846    4.046154    4.015385   3.092308   4.969231
# SL              3.258065    4.483871    4.064516   3.403226   5.145161
#
#             post_away_score  post_home_score  post_bat_score  post_fld_score  \
# pitch_type
# FF                 4.085533         4.309398        3.275607        5.119324
# FS                 4.030769         4.046154        3.107692        4.969231
# SL                 4.064516         4.483871        3.403226        5.145161
#
#              spin_axis  delta_home_win_exp  delta_run_exp  is_strike  \
# pitch_type
# FF          169.105597           -0.000472      -0.002592   0.712777
# FS          139.630769           -0.012369       0.019600   0.600000
# SL          252.419355            0.000097      -0.022871   0.564516
#
#             plate_-x     pfx_-x  bauer_units  swing_miss
# pitch_type
# FF          0.024308  -3.786019    23.700277    0.120380
# FS         -0.446154 -13.619077    25.521243    0.123077
# SL          0.736129   8.701935    29.929440    0.193548

# %%
doolittle.pitch_type.value_counts(normalize=True)
# Out:
# FF    0.881750
# FS    0.060521
# SL    0.057728
# Name: pitch_type, dtype: float64
