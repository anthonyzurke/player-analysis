# %%
fried = pd.read_csv('./data/max-fried.csv')
fried.drop(columns = ['Unnamed: 0'], inplace = True)

# Font Dictionary
font_title = {
    'size': 12,
    'weight': 'bold',
    'verticalalignment': 'center_baseline',
    'horizontalalignment': 'center'
}

pd.set_option('max_columns', None)
print(fried.shape)
fried.head()
# Out:
# (2558, 89)
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         FF  2021-09-29           95.2           1.29           6.11
# 1         SL  2021-09-29           82.9           1.86           5.87
# 2         SL  2021-09-29           86.7           1.65           5.93
# 3         SL  2021-09-29           85.3           1.68           5.91
# 4         CH  2021-09-29           87.4           1.93           5.66
#
#   player_name  batter  pitcher events    description  zone  \
# 0  Fried, Max  544369   608331    out  hit_into_play     5
# 1  Fried, Max  544369   608331    NaN           ball    13
# 2  Fried, Max  544369   608331    NaN  called_strike     2
# 3  Fried, Max  663837   608331    out  hit_into_play     8
# 4  Fried, Max  663837   608331    NaN           ball    14
#
#                                                  des game_type stand p_throws  \
# 0  Didi Gregorius pops out to third baseman Austi...         R     L        L
# 1  Didi Gregorius pops out to third baseman Austi...         R     L        L
# 2  Didi Gregorius pops out to third baseman Austi...         R     L        L
# 3  Matt Vierling grounds out sharply, shortstop D...         R     R        L
# 4  Matt Vierling grounds out sharply, shortstop D...         R     R        L
#
#   home_team away_team type  hit_location      bb_type  balls  strikes  \
# 0       ATL       PHI    X           5.0        popup      1        1
# 1       ATL       PHI    B           NaN          NaN      0        1
# 2       ATL       PHI    S           NaN          NaN      0        0
# 3       ATL       PHI    X           6.0  ground_ball      1        2
# 4       ATL       PHI    B           NaN          NaN      0        2
#
#    game_year  pfx_x   pfx_z  plate_x  plate_z  on_3b  on_2b  on_1b  \
# 0       2021   0.11  103.68    -0.19     2.30    NaN    NaN    NaN
# 1       2021  -0.34   50.40    -1.13     1.67    NaN    NaN    NaN
# 2       2021  -0.35  203.04    -0.26     3.28    NaN    NaN    NaN
# 3       2021  -0.09  -30.24    -0.06     1.66    NaN    NaN    NaN
# 4       2021   1.17   -1.44     1.98     0.55    NaN    NaN    NaN
#
#    outs_when_up  inning inning_topbot    hc_x    hc_y  fielder_2       vx0  \
# 0             2       7           Top   95.45  160.60     518595 -4.186734
# 1             2       7           Top     NaN     NaN     518595 -6.190763
# 2             2       7           Top     NaN     NaN     518595 -3.844511
# 3             1       7           Top  111.05  163.34     518595 -3.922249
# 4             1       7           Top     NaN     NaN     518595 -2.317153
#
#           vy0       vz0         ax         ay         az  sz_top  sz_bot  \
# 0 -138.493824 -7.099702   2.375019  30.306117 -15.310607    3.49    1.60
# 1 -120.574782 -2.771056  -1.998025  24.639602 -33.409263    3.49    1.60
# 2 -126.288617  0.569788  -2.988297  25.288069 -36.362246    3.49    1.63
# 3 -124.279030 -3.036532  -0.161456  24.331685 -35.432809    3.49    1.60
# 4 -127.171078 -6.991725  13.196216  27.240141 -26.572564    3.54    1.70
#
#    hit_distance_sc  launch_speed  launch_angle  effective_speed  \
# 0            127.0          89.2          69.0             95.9
# 1              NaN           NaN           NaN             82.7
# 2              NaN           NaN           NaN             86.8
# 3             18.0         108.9          -5.0             85.6
# 4              NaN           NaN           NaN             87.6
#
#    release_spin_rate  release_extension  game_pk  pitcher.1  fielder_2.1  \
# 0               2109                6.7   632306     608331       518595
# 1               2171                6.3   632306     608331       518595
# 2               2464                6.2   632306     608331       518595
# 3               2451                6.3   632306     608331       518595
# 4               1267                6.5   632306     608331       518595
#
#    fielder_3  fielder_4  fielder_5  fielder_6  fielder_7  fielder_8  \
# 0     518692     645277     663586     621020     592696     594807
# 1     518692     645277     663586     621020     592696     594807
# 2     518692     645277     663586     621020     592696     594807
# 3     518692     645277     663586     621020     592696     594807
# 4     518692     645277     663586     621020     592696     594807
#
#    fielder_9  release_pos_y  estimated_ba_using_speedangle  \
# 0     624585          53.81                          0.009
# 1     624585          54.17                            NaN
# 2     624585          54.26                            NaN
# 3     624585          54.15                          0.449
# 4     624585          53.98                            NaN
#
#    estimated_woba_using_speedangle  woba_value  woba_denom  babip_value  \
# 0                            0.009         0.0         1.0          0.0
# 1                              NaN         NaN         NaN          NaN
# 2                              NaN         NaN         NaN          NaN
# 3                            0.428         0.0         1.0          0.0
# 4                              NaN         NaN         NaN          NaN
#
#    iso_value  launch_speed_angle  at_bat_number  pitch_number  \
# 0        0.0                 3.0             52             3
# 1        NaN                 NaN             52             2
# 2        NaN                 NaN             52             1
# 3        0.0                 2.0             51             4
# 4        NaN                 NaN             51             3
#
#         pitch_name  home_score  away_score  bat_score  fld_score  \
# 0  4-Seam Fastball           3           2          2          3
# 1           Slider           3           2          2          3
# 2           Slider           3           2          2          3
# 3           Slider           3           2          2          3
# 4         Changeup           3           2          2          3
#
#    post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 0                2                3               2               3
# 1                2                3               2               3
# 2                2                3               2               3
# 3                2                3               2               3
# 4                2                3               2               3
#
#   if_fielding_alignment of_fielding_alignment  spin_axis  delta_home_win_exp  \
# 0              Standard              Standard        159               0.020
# 1              Standard              Standard        295               0.000
# 2              Standard              Standard        287               0.000
# 3              Standard              Standard        288               0.031
# 4              Standard              Standard        130               0.000
#
#    delta_run_exp  is_strike pitch_count  plate_-x  pfx_-x  swing_miss
# 0         -0.099          1         1-1      0.49  178.56           0
# 1          0.014          0         0-1     -0.23  230.40           0
# 2         -0.018          1         0-0      1.53  191.52           0
# 3         -0.114          1         1-2     -0.23  -76.32           0
# 4          0.013          0         0-2     -0.21  -30.24           0
